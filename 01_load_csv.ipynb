# %%
import pandas as pd

data = {
    "Name": ["Rahul", "Ananya", "Vikram", "Priya", "Arjun",
             "Sneha", "Kiran", "Meera", "Rohan", "Divya", "Amit", "Neha"],
    "Age": [20, 21, 19, 22, 20, 21, 23, 19, 22, 20, 21, 22],
    "Marks": [85, 91, 78, 88, 95, 82, 76, 89, 93, 84, 87, 90],
    "City": ["Hyderabad", "Bengaluru", "Chennai", "Hyderabad",
             "Mumbai", "Pune", "Delhi", "Chennai",
             "Bengaluru", "Mumbai", "Pune", "Delhi"]
}

df = pd.DataFrame(data)

df.to_csv("student_data.csv", index=False)

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
df.to_csv("student_data.csv", index=False)

# %%
df = pd.read_csv("student_data.csv")

print(df.head(10))
# Out:
#      Name  Age  Marks       City
# 0   Rahul   20     85  Hyderabad
# 1  Ananya   21     91  Bengaluru
# 2  Vikram   19     78    Chennai
# 3   Priya   22     88  Hyderabad
# 4   Arjun   20     95     Mumbai
# 5   Sneha   21     82       Pune
# 6   Kiran   23     76      Delhi
# 7   Meera   19     89    Chennai
# 8   Rohan   22     93  Bengaluru
# 9   Divya   20     84     Mumbai
